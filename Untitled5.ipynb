# %% [markdown]
# <a href="https://colab.research.google.com/github/izabelasouza07-maisa/amigo-secreto/blob/main/Untitled5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df = pd.read_csv('/content/loja_livro_filmes.csv')

# %%
df_paises = df.groupby(['pais'])['unidades'].sum().nlargest(9).copy()
df_paises = df_paises.reset_index()

# %%
df_paises.columns = ['País', 'Unidades pedidas']
df_paises['Ranking'] = df_paises.index + 1
df_paises.set_index('Ranking', inplace=True)
df_paises
# Out:
#               País  Unidades pedidas
# Ranking
# 2        Argentina              5591
# 3          Equador              5566
# 4         Paraguai              5564
# 5             Peru              5550
# 6        Venezuela              5529
# 7         Colômbia              5504
# 8           Brasil              5473
# 9          Uruguai              5377
# 10           Chile              5304

# %%
s_pais = df_paises.style
s_pais = s_pais.format({'Unidades pedidas': '{}prod'})
s_pais
# Out:
# <style type="text/css">
# </style>
# <table id="T_bbc65" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_bbc65_level0_col0" class="col_heading level0 col0" >País</th>
#       <th id="T_bbc65_level0_col1" class="col_heading level0 col1" >Unidades pedidas</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Ranking</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_bbc65_level0_row0" class="row_heading level0 row0" >2</th>
#       <td id="T_bbc65_row0_col0" class="data row0 col0" >Argentina</td>
#       <td id="T_bbc65_row0_col1" class="data row0 col1" >5591prod</td>
#     </tr>
#     <tr>
#       <th id="T_bbc65_level0_row1" class="row_heading level0 row1" >3</th>
#       <td id="T_bbc65_row1_col0" class="data row1 col0" >Equador</td>
#       <td id="T_bbc65_row1_col1" class="data row1 col1" >5566prod</td>
#     </tr>
#     <tr>
#       <th id="T_bbc65_level0_row2" class="row_heading level0 row2" >4</th>
#       <td id="T_bbc65_row2_col0" class="data row2 col0" >Paraguai</td>
#       <td id="T_bbc65_row2_col1" class="data row2 col1" >5564prod</td>
#     </tr>
#     <tr>
#       <th id="T_bbc65_level0_row3" class="row_heading level0 row3" >5</th>
#       <td id="T_bbc65_row3_col0" class="data row3 col0" >Peru</td>
#       <td id="T_bbc65_row3_col1" class="data row3 col1" >5550prod</td>
#     </tr>
#     <tr>
#       <th id="T_bbc65_level0_row4" class="row_heading level0 row4" >6</th>
#       <td id="T_bbc65_row4_col0" class="data row4 col0" >Venezuela</td>
#       <td id="T_bbc65_row4_col1" class="data row4 col1" >5529prod</td>
#     </tr>
#     <tr>
#       <th id="T_bbc65_level0_row5" class="row_heading level0 row5" >7</th>
#       <td id="T_bbc65_row5_col0" class="data row5 col0" >Colômbia</td>
#       <td id="T_bbc65_row5_col1" class="data row5 col1" >5504prod</td>
#     </tr>
#     <tr>
#       <th id="T_bbc65_level0_row6" class="row_heading level0 row6" >8</th>
#       <td id="T_bbc65_row6_col0" class="data row6 col0" >Brasil</td>
#       <td id="T_bbc65_row6_col1" class="data row6 col1" >5473prod</td>
#     </tr>
#     <tr>
#       <th id="T_bbc65_level0_row7" class="row_heading level0 row7" >9</th>
#       <td id="T_bbc65_row7_col0" class="data row7 col0" >Uruguai</td>
#       <td id="T_bbc65_row7_col1" class="data row7 col1" >5377prod</td>
#     </tr>
#     <tr>
#       <th id="T_bbc65_level0_row8" class="row_heading level0 row8" >10</th>
#       <td id="T_bbc65_row8_col0" class="data row8 col0" >Chile</td>
#       <td id="T_bbc65_row8_col1" class="data row8 col1" >5304prod</td>
#     </tr>
#   </tbody>
# </table>

# %%
df_produto_custo = df.groupby(['categoria'])[['custo_produto']].sum()
df_produto_custo.index.name = 'Categoria produto'
df_produto_custo.columns = ['Custo de pedidos']
df_produto_custo
# Out:
#                    Custo de pedidos
# Categoria produto
# BlueRay                    14191.36
# CD                         10514.28
# Coleção                    73128.59
# Livro                      78213.80

# %%
s_produto = df_produto_custo.style
s_produto.format('R${:,.2f}')\
         .highlight_max(color='#F16165')\
         .highlight_min(color='lightgreen')
# Out:
# <style type="text/css">
# #T_a034a_row1_col0 {
#   background-color: lightgreen;
# }
# #T_a034a_row3_col0 {
#   background-color: #F16165;
# }
# </style>
# <table id="T_a034a" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a034a_level0_col0" class="col_heading level0 col0" >Custo de pedidos</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Categoria produto</th>
#       <th class="blank col0" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a034a_level0_row0" class="row_heading level0 row0" >BlueRay</th>
#       <td id="T_a034a_row0_col0" class="data row0 col0" >R$14,191.36</td>
#     </tr>
#     <tr>
#       <th id="T_a034a_level0_row1" class="row_heading level0 row1" >CD</th>
#       <td id="T_a034a_row1_col0" class="data row1 col0" >R$10,514.28</td>
#     </tr>
#     <tr>
#       <th id="T_a034a_level0_row2" class="row_heading level0 row2" >Coleção</th>
#       <td id="T_a034a_row2_col0" class="data row2 col0" >R$73,128.59</td>
#     </tr>
#     <tr>
#       <th id="T_a034a_level0_row3" class="row_heading level0 row3" >Livro</th>
#       <td id="T_a034a_row3_col0" class="data row3 col0" >R$78,213.80</td>
#     </tr>
#   </tbody>
# </table>

# %%
df_descontos = pd.DataFrame(df['tipo_desconto'].value_counts())
df_descontos.columns = ['Nº pedidos']
df_descontos.index.name = 'Tipo desconto'

porcentagem = df_descontos['Nº pedidos'].to_numpy()
porcentagem = 100* porcentagem/porcentagem.sum()
df_descontos['Distribuição de pedidos'] = porcentagem
df_descontos
# Out:
#                Nº pedidos  Distribuição de pedidos
# Tipo desconto
# Sem desconto        13347                53.623945
# Cyber Monday         6922                27.810366
# Black Friday         1986                 7.979108
# Liquidação           1487                 5.974287
# Data especial        1148                 4.612294

# %%
s_descontos = df_descontos.style
cabecalho = {
    'selector': 'th',
    'props': 'font-weight: bold; font-family: Arial; text-align: right; backgroud-color: white; color: black; '
    }
celulas = {
    'selector': 'td',
    'props': 'backgroud-color: white; color: black;'
}
s_descontos.set_table_styles([cabecalho, celulas], overwrite=False)
s_descontos.format({'Distribuição de pedidos': '{:.2f}%'})\
    .bar(subset=['Distribuição de pedidos'], vmin=0, vmax=100.0, color='#093364', height=50, width=60)
# Out:
# <style type="text/css">
# #T_ce914 th {
#   font-weight: bold;
#   font-family: Arial;
#   text-align: right;
#   backgroud-color: white;
#   color: black;
# }
# #T_ce914 td {
#   backgroud-color: white;
#   color: black;
# }
# #T_ce914_row0_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #093364 32.2%, transparent 32.2%) no-repeat center;
#   background-size: 100% 50.0%;
# }
# #T_ce914_row1_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #093364 16.7%, transparent 16.7%) no-repeat center;
#   background-size: 100% 50.0%;
# }
# #T_ce914_row2_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #093364 4.8%, transparent 4.8%) no-repeat center;
#   background-size: 100% 50.0%;
# }
# #T_ce914_row3_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #093364 3.6%, transparent 3.6%) no-repeat center;
#   background-size: 100% 50.0%;
# }
# #T_ce914_row4_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #093364 2.8%, transparent 2.8%) no-repeat center;
#   background-size: 100% 50.0%;
# }
# </style>
# <table id="T_ce914" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_ce914_level0_col0" class="col_heading level0 col0" >Nº pedidos</th>
#       <th id="T_ce914_level0_col1" class="col_heading level0 col1" >Distribuição de pedidos</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Tipo desconto</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ce914_level0_row0" class="row_heading level0 row0" >Sem desconto</th>
#       <td id="T_ce914_row0_col0" class="data row0 col0" >13347</td>
#       <td id="T_ce914_row0_col1" class="data row0 col1" >53.62%</td>
#     </tr>
#     <tr>
#       <th id="T_ce914_level0_row1" class="row_heading level0 row1" >Cyber Monday</th>
#       <td id="T_ce914_row1_col0" class="data row1 col0" >6922</td>
#       <td id="T_ce914_row1_col1" class="data row1 col1" >27.81%</td>
#     </tr>
#     <tr>
#       <th id="T_ce914_level0_row2" class="row_heading level0 row2" >Black Friday</th>
#       <td id="T_ce914_row2_col0" class="data row2 col0" >1986</td>
#       <td id="T_ce914_row2_col1" class="data row2 col1" >7.98%</td>
#     </tr>
#     <tr>
#       <th id="T_ce914_level0_row3" class="row_heading level0 row3" >Liquidação</th>
#       <td id="T_ce914_row3_col0" class="data row3 col0" >1487</td>
#       <td id="T_ce914_row3_col1" class="data row3 col1" >5.97%</td>
#     </tr>
#     <tr>
#       <th id="T_ce914_level0_row4" class="row_heading level0 row4" >Data especial</th>
#       <td id="T_ce914_row4_col0" class="data row4 col0" >1148</td>
#       <td id="T_ce914_row4_col1" class="data row4 col1" >4.61%</td>
#     </tr>
#   </tbody>
# </table>
